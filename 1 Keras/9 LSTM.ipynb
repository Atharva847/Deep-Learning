# %%
import numpy as np
from tensorflow.keras.datasets import imdb
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
(X_train, y_train), (X_test, y_test) = imdb.load_data()

# %%
word_index = imdb.get_word_index()
vocab_size = len(word_index) + 3
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb_word_index.json
# 1641221/1641221 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
max_len = 200

X_train = pad_sequences(X_train, maxlen=max_len)
X_test = pad_sequences(X_test, maxlen=max_len)

# %%
model = Sequential()

model.add(Embedding(input_dim=vocab_size, output_dim=128, input_length=max_len))

model.add(LSTM(64))

model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %%
model.fit(
    X_train, y_train,
    epochs=15,
    batch_size=64,
    validation_split=0.2
)
# Out:
# Epoch 1/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.8055 - loss: 0.4218 - val_accuracy: 0.8574 - val_loss: 0.3338
# Epoch 2/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9299 - loss: 0.1915 - val_accuracy: 0.8648 - val_loss: 0.3478
# Epoch 3/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9712 - loss: 0.0861 - val_accuracy: 0.8656 - val_loss: 0.3536
# Epoch 4/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9793 - loss: 0.0634 - val_accuracy: 0.8706 - val_loss: 0.4647
# Epoch 5/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9806 - loss: 0.0584 - val_accuracy: 0.8618 - val_loss: 0.5271
# Epoch 6/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9907 - loss: 0.0289 - val_accuracy: 0.8654 - val_loss: 0.5185
# Epoch 7/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9916 - loss: 0.0291 - val_accuracy: 0.8670 - val_loss: 0.5450
# Epoch 8/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9946 - loss: 0.0176 - val_accuracy: 0.8590 - val_loss: 0.5847
# Epoch 9/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9930 - loss: 0.0210 - val_accuracy: 0.8568 - val_loss: 0.5503
# Epoch 10/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.9965 - loss: 0.0122 - val_accuracy: 0.8548 - val_loss: 0.7048
# Epoch 11/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9965 - loss: 0.0111 - val_accuracy: 0.8592 - val_loss: 0.7587
# Epoch 12/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.9967 - loss: 0.0111 - val_accuracy: 0.8610 - val_loss: 0.7241
# Epoch 13/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9998 - loss: 0.0013 - val_accuracy: 0.8612 - val_loss: 0.8120
# Epoch 14/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9999 - loss: 2.6304e-04 - val_accuracy: 0.8612 - val_loss: 0.8520
# Epoch 15/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 1.0000 - loss: 1.0585e-04 - val_accuracy: 0.8636 - val_loss: 0.9389

# %%
loss, acc = model.evaluate(X_test, y_test)
print("Test Accuracy:", acc)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.8479 - loss: 1.0734
# Test Accuracy: 0.8479200005531311
