# %%
import numpy as np
from tensorflow.keras.datasets import imdb
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, GRU
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
(X_train, y_train), (X_test, y_test) = imdb.load_data()

# %%
word_index = imdb.get_word_index()
vocab_size = len(word_index) + 3
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb_word_index.json
# 1641221/1641221 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
max_len = 200

X_train = pad_sequences(X_train, maxlen=max_len)
X_test = pad_sequences(X_test, maxlen=max_len)

# %%
model = Sequential()

model.add(Embedding(input_dim=vocab_size, output_dim=128, input_length=max_len))

model.add(GRU(64))

model.add(Dense(1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %%
model.fit(
    X_train, y_train,
    epochs=15,
    batch_size=64,
    validation_split=0.2
)
# Out:
# Epoch 1/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.7793 - loss: 0.4440 - val_accuracy: 0.8620 - val_loss: 0.3254
# Epoch 2/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9234 - loss: 0.2015 - val_accuracy: 0.8442 - val_loss: 0.3923
# Epoch 3/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9674 - loss: 0.0988 - val_accuracy: 0.8648 - val_loss: 0.3821
# Epoch 4/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9839 - loss: 0.0498 - val_accuracy: 0.8526 - val_loss: 0.4206
# Epoch 5/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9913 - loss: 0.0282 - val_accuracy: 0.8616 - val_loss: 0.6008
# Epoch 6/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9929 - loss: 0.0219 - val_accuracy: 0.8602 - val_loss: 0.5905
# Epoch 7/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9967 - loss: 0.0106 - val_accuracy: 0.8614 - val_loss: 0.7084
# Epoch 8/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9983 - loss: 0.0062 - val_accuracy: 0.8564 - val_loss: 0.7573
# Epoch 9/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9985 - loss: 0.0050 - val_accuracy: 0.8598 - val_loss: 0.8371
# Epoch 10/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9996 - loss: 0.0015 - val_accuracy: 0.8478 - val_loss: 1.0446
# Epoch 11/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9970 - loss: 0.0086 - val_accuracy: 0.8578 - val_loss: 0.8052
# Epoch 12/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - accuracy: 0.9979 - loss: 0.0064 - val_accuracy: 0.8604 - val_loss: 0.7896
# Epoch 13/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9984 - loss: 0.0056 - val_accuracy: 0.8646 - val_loss: 0.8375
# Epoch 14/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9994 - loss: 0.0021 - val_accuracy: 0.8426 - val_loss: 0.9401
# Epoch 15/15
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9999 - loss: 6.0007e-04 - val_accuracy: 0.8566 - val_loss: 0.8929

# %%
loss, acc = model.evaluate(X_test, y_test)
print("Test Accuracy:", acc)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8420 - loss: 0.9393
# Test Accuracy: 0.8419600129127502
